# %%
import numpy as np
import pandas as pd
import scipy as scp
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve,roc_auc_score,accuracy_score,precision_score,recall_score
import tensorflow as tf
import keras_tuner as kt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout
from sklearn.utils.class_weight import compute_class_weight
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.utils import shuffle

# %%
df_crime=pd.read_csv('archive_3/Crime_Data_2010_2017.csv')
df_crime['arrest']=np.zeros(1584316)
#df_crime2=pd.read_csv('smaller_df.csv') uncomment to use with smaller dataset
#df_crime2['arrest']=np.zeros(30000) 
#df_crime2=df_crime2.drop('Unnamed: 0',axis=1)

# 'Date Reported' and 'Date Occurred' to datetime format
df_crime['Date Reported'] = pd.to_datetime(df_crime['Date Reported'])
df_crime['Date Occurred'] = pd.to_datetime(df_crime['Date Occurred'])

# number of days between 'Date Occurred' and 'Date Reported'
df_crime['Days Between'] = (df_crime['Date Reported'] - df_crime['Date Occurred']).dt.days

df_crime.arrest[np.logical_or(df_crime['Status Code']=='AA', df_crime['Status Code']=='JA')]=1
np.any(df_crime.arrest==1)
df_signal=df_crime[df_crime.arrest==1]
df_background=df_crime[df_crime['Status Code']=='IC']
df_crime['Days Between']
# Out:
# /var/folders/dq/2mrk7ns11xgbpp7p6mrkfhr00000gn/T/ipykernel_971/3759796357.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_crime.arrest[np.logical_or(df_crime['Status Code']=='AA', df_crime['Status Code']=='JA')]=1
# /var/folders/dq/2mrk7ns11xgbpp7p6mrkfhr00000gn/T/ipykernel_971/3759796357.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_crime.arrest[np.logical_or(df_crime['Status Code']=='AA', df_crime['Status Code']=='JA')]=1
# 0           3
# 1           3
# 2           1
# 3           1
# 4           7
#            ..
# 1584311     0
# 1584312     0
# 1584313    46
# 1584314     0
# 1584315    58
# Name: Days Between, Length: 1584316, dtype: int64

# %%
df_crime["Date Occurred"], df_crime["Date Reported"]
# Out:
# (0         2013-03-11
#  1         2010-01-22
#  2         2013-03-18
#  3         2010-11-10
#  4         2014-01-04
#               ...
#  1584311   2017-09-07
#  1584312   2017-09-07
#  1584313   2017-07-15
#  1584314   2017-09-08
#  1584315   2017-07-12
#  Name: Date Occurred, Length: 1584316, dtype: datetime64[ns],
#  0         2013-03-14
#  1         2010-01-25
#  2         2013-03-19
#  3         2010-11-11
#  4         2014-01-11
#               ...
#  1584311   2017-09-07
#  1584312   2017-09-07
#  1584313   2017-08-30
#  1584314   2017-09-08
#  1584315   2017-09-08
#  Name: Date Reported, Length: 1584316, dtype: datetime64[ns])

# %%
merged=pd.concat((df_background,df_signal))
#numeric=['DR Number','Time Occurred','Area ID','Reporting District','Crime Code','Victim Age','Premise Code','arrest']
selected_onehot=['DR Number','Time Occurred','Area ID','Reporting District','Crime Code','Victim Age','Premise Code','arrest','Crime Code Description','Premise Description','Victim Descent','Victim Sex']
#merged=merged[numeric]
merged=merged[selected_onehot]
merged=merged.dropna(how='any',axis=0)
X=merged.drop(['arrest'],axis=1)
Y=merged['arrest']
selected_features=['Crime Code','Area ID','Premise Code']
X=X[selected_features]

# %%
merged_embed=pd.concat((df_background,df_signal))
selected_onehot=['DR Number','Time Occurred','Area ID','Reporting District','Crime Code','Victim Age','Premise Code','arrest','Crime Code Description','Premise Description','Victim Descent','Victim Sex','Days Between']
merged_embed=merged_embed[selected_onehot]
merged_embed=merged_embed.dropna(how='any',axis=0)

# %%
from sklearn.preprocessing import MinMaxScaler
def set_features(X_train_embed,X_test_embed):
    LabelCD=LabelEncoder() #Onehot encoding of the training features
    LabelRD=LabelEncoder()
    age_fit=np.array(merged_embed['Victim Age'])
    age_fit=age_fit.reshape((np.size(age_fit),1))
    TO_fit=np.array(merged_embed['Time Occurred'])
    TO_fit=TO_fit.reshape((np.size(TO_fit),1))
    DB_fit=np.array(merged_embed['Days Between'])
    DB_fit=DB_fit.reshape((np.size(DB_fit),1))
    mm_scaler_age=MinMaxScaler()
    mm_scaler_TO=MinMaxScaler()
    mm_scaler_DB=MinMaxScaler()
    LabelSD=LabelEncoder()
    LabelVD=LabelEncoder()
    mm_scaler_age.fit(age_fit)
    mm_scaler_TO.fit(TO_fit)
    mm_scaler_DB.fit(DB_fit)
    LabelSD.fit(merged_embed['Victim Sex'])
    LabelCD.fit(merged_embed['Crime Code Description'])
    LabelVD.fit(merged_embed['Victim Descent'])
    LabelRD.fit(merged_embed['Reporting District'])
    age=np.array(X_train_embed['Victim Age'])
    age=age.reshape((np.size(age),1))
    age=mm_scaler_age.transform(age)
    Code_hot=LabelCD.transform(X_train_embed['Crime Code Description'])
    Code_embed=tf.keras.utils.to_categorical(Code_hot)
    Code_embed=np.concatenate((Code_embed,age),axis=1)
    SD_onehot=LabelSD.transform(X_train_embed['Victim Sex'])
    SD_onehot=tf.keras.utils.to_categorical(SD_onehot)
    VD_onehot=LabelVD.transform(X_train_embed['Victim Descent'])
    VD_onehot=tf.keras.utils.to_categorical(VD_onehot)
    Area_onehot=tf.keras.utils.to_categorical(X_train_embed['Area ID']-1)
    TO=np.array(X_train_embed['Time Occurred'])
    TO=TO.reshape((np.size(TO),1))
    TO=mm_scaler_TO.transform(TO)
    DB=np.array(X_train_embed['Days Between'])
    DB=DB.reshape((np.size(DB),1))
    DB=mm_scaler_DB.transform(DB)
    RD=LabelRD.transform(X_train_embed['Reporting District'])
    RD=tf.keras.utils.to_categorical(RD)
    Code_embed=np.concatenate((Code_embed,TO),axis=1)
    #print(np.shape(Code_embed))
    Code_embed=np.concatenate((Code_embed,Area_onehot),axis=1)
    #print(np.shape(Code_embed))
    Code_embed=np.concatenate((Code_embed,SD_onehot),axis=1)
    #print(np.shape(Code_embed))
    Code_embed=np.concatenate((Code_embed,VD_onehot),axis=1)
    #print(np.shape(Code_embed))
    LabelPD=LabelEncoder()
    LabelPD.fit(merged_embed['Premise Description'])
    Premise_hot=LabelPD.transform(X_train_embed['Premise Description'])
    Premise_embed=tf.keras.utils.to_categorical(Premise_hot)
    Code_embed=np.concatenate((Code_embed,Premise_embed),axis=1)
    Code_embed=np.concatenate((Code_embed,RD),axis=1)
    Code_embed=np.concatenate((Code_embed,DB),axis=1)
    #print(np.shape(Code_embed))
    Onehot_test=LabelCD.transform(X_test_embed['Crime Code Description']) #Onehot encoding of testing set
    Onehot_test=tf.keras.utils.to_categorical(Onehot_test)
    age_test=np.array(X_test_embed['Victim Age'])
    age_test=age_test.reshape((np.size(age_test),1))
    age_test=mm_scaler_age.transform(age_test)
    Area_test=tf.keras.utils.to_categorical(X_test_embed['Area ID']-1)
    TO_test=np.array(X_test_embed['Time Occurred'])
    TO_test=TO_test.reshape((np.size(TO_test),1))
    TO_test=mm_scaler_TO.transform(TO_test)
    RD_test=LabelRD.transform(X_test_embed['Reporting District'])
    RD_test=tf.keras.utils.to_categorical(RD_test)
    SD_test=LabelSD.transform(X_test_embed['Victim Sex'])
    SD_test=tf.keras.utils.to_categorical(SD_test)
    VD_test=LabelVD.transform(X_test_embed['Victim Descent'])
    VD_test=tf.keras.utils.to_categorical(VD_test)
    Prem_test=LabelPD.transform(X_test_embed['Premise Description'])
    Prem_test=tf.keras.utils.to_categorical(Prem_test)
    DB_test=np.array(X_test_embed['Days Between'])
    DB_test=DB_test.reshape((np.size(TO_test),1))
    DB_test=mm_scaler_DB.transform(TO_test)
    Onehot_test
    Onehot_test=np.concatenate((Onehot_test,age_test),axis=1)
    Onehot_test=np.concatenate((Onehot_test,TO_test),axis=1)
    Onehot_test=np.concatenate((Onehot_test,Area_test),axis=1)
    Onehot_test=np.concatenate((Onehot_test,SD_test),axis=1)
    Onehot_test=np.concatenate((Onehot_test,VD_test),axis=1)
    Onehot_test=np.concatenate((Onehot_test,Prem_test),axis=1)
    Onehot_test=np.concatenate((Onehot_test,RD_test),axis=1)
    Onehot_test=np.concatenate((Onehot_test,DB_test),axis=1)
    return Code_embed, Onehot_test

# %%
#merged_embed=pd.concat((df_background,df_signal))
#selected_onehot=['DR Number','Time Occurred','Area ID','Reporting District','Crime Code','Victim Age','Premise Code','arrest','Crime Code Description','Premise Description','Victim Descent','Victim Sex','Days Between']
#merged_embed=merged_embed[selected_onehot]
#merged_embed=merged_embed.dropna(how='any',axis=0)
X_train_embed,X_test_embed,Y_train_embed,Y_test_embed=train_test_split(merged_embed.drop('arrest',axis=1),merged_embed['arrest'],test_size=0.3,random_state=41)
Code_embed, Onehot_test=set_features(X_train_embed,X_test_embed)

# %%
Code_embed_train,Code_embed_val,Y_embed_train,Y_embed_val=train_test_split(Code_embed,Y_train_embed,test_size=0.3,random_state=41)

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=41)
#X_train_bdt,X_val_bdt,Y_train_bdt,Y_val_bdt=train_test_split(X_train,Y_train,test_size=0.3,random_state=41)
train_weights=np.ones(np.size(Y))
weight_s=1-(np.size(Y[Y==1])/(np.size(Y[Y==1])+np.size(Y[Y==0])))
weight_b=1-(np.size(Y[Y==0])/(np.size(Y[Y==1])+np.size(Y[Y==0])))
train_weights[Y==1]=train_weights[Y==1]*weight_s
train_weights[Y==0]=train_weights[Y==0]*weight_b
knn_c=KNeighborsClassifier(8)
rdf=RandomForestClassifier(class_weight='balanced')
#knn_c.fit(X_train,Y_train)
#predict=knn_c.predict(X_test)
#rdf.fit(X_train_bdt,Y_train_bdt)
rdf.fit(X_train,Y_train)
predict=rdf.predict_proba(X_test)[:,1]
roc_auc_score(Y_test,predict)
# Out:
# 0.8103052972567901

# %%
predict_proba=rdf.predict_proba(X_test)
tpr,fpr,thresholds=roc_curve(Y_test,predict_proba[:,1])
#predict_proba2=rdf_2.predict_proba(X_test2)
#tpr2,fpr2,thresholds2=roc_curve(Y_test2,predict_proba2[:,1])
plt.plot(tpr,fpr)

# %%
plt.hist((predict_proba[:,1])[Y_test==1],bins=30,histtype='step',label='arrest')
plt.hist((predict_proba[:,1])[Y_test==0],bins=30,histtype='step',label='no arrest')
plt.ylabel('counts')
plt.xlabel('prediction')
plt.legend()
plt.yscale('log')
plt.savefig('distribution_rdf.pdf')

# %%
from sklearn.ensemble import HistGradientBoostingClassifier
HGC=HistGradientBoostingClassifier(categorical_features=[True,True,True],class_weight='balanced')
HGC.fit(X_train,Y_train)
predict_HGC=HGC.predict_proba(X_test)[:,1]
roc_auc_score(Y_test,predict_HGC)
# Out:
# 0.8323484030681745

# %%
plt.hist((predict_HGC)[Y_test==1],bins=30,histtype='step',label='arrest')
plt.hist((predict_HGC)[Y_test==0],bins=30,histtype='step',label='no arrest')
plt.ylabel('counts')
plt.xlabel('prediction')
plt.legend()
plt.yscale('log')

# %%
tpr_HGC,fpr_HGC,thresholds_HGC=roc_curve(Y_test,predict_HGC)
plt.plot(tpr_HGC,fpr_HGC)

# %%
#opti=tf.keras.optimizers.Adam(learning_rate=5*10**(-6))
#embed_model.compile(loss='binary_crossentropy',optimizer=opti,metrics=['accuracy','precision','AUC'])
class_weights_embed=compute_class_weight(class_weight='balanced',classes=np.unique(Y_train_embed),y=Y_train_embed)
class_weight_dict_embed = dict(enumerate(class_weights_embed))
class_weight_dict_embed
# Out:
# {0: 0.5733099035928432, 1: 3.9101804496767345}

# %%
from tensorflow.keras.callbacks import Callback
class HistoryEpoch(Callback):
    def __init__(self, data):
        self.data = data

    def on_epoch_end(self, epoch, logs={}):
        x, y = self.data
        l, a, p, AUC = self.model.evaluate(x, y, verbose=0)
        logs['train_loss'] = l
        logs['train_accuracy'] = a
        logs['train_precision'] = p
        logs['train_AUC'] = AUC

# %%
X_test_random=X_test_embed.copy()
print(X_test_random)
X_test_random['Victim Age']=np.random.uniform(0,99,np.size(X_test_random['Victim Age']))
unnötig,test_random_ages=set_features(X_train_embed,X_test_random)
test_random_ages
# Out:
#          DR Number  Time Occurred  Area ID  Reporting District  Crime Code  \
# 1239698  160324856           2000        3                 359         480
# 1186339  152010187           1600       20                2033         420
# 687145   121908273            130       19                1963         745
# 1497089  171409100           1400       14                1452         330
# 896171   141214707           1310       12                1211         310
# ...            ...            ...      ...                 ...         ...
# 527661   120218770            900        2                 205         310
# 1005879  150204734            950        2                 269         624
# 618143   121213396           1615       12                1283         330
# 165255   101810441           1020       18                1863         624
# 131799   101427619           1000       14                1434         310
#
#          Victim Age  Premise Code  \
# 1239698        21.0         101.0
# 1186339        76.0         222.0
# 687145         26.0         502.0
# 1497089        48.0         101.0
# 896171         38.0         501.0
# ...             ...           ...
# 527661         26.0         502.0
# 1005879        23.0         123.0
# 618143         43.0         101.0
# 165255         22.0         501.0
# 131799         47.0         501.0
#
#                                   Crime Code Description  \
# 1239698                                    BIKE - STOLEN
# 1186339  THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
# 687145          VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 1497089                            BURGLARY FROM VEHICLE
# 896171                                          BURGLARY
# ...                                                  ...
# 527661                                          BURGLARY
# 1005879                         BATTERY - SIMPLE ASSAULT
# 618143                             BURGLARY FROM VEHICLE
# 165255                          BATTERY - SIMPLE ASSAULT
# 131799                                          BURGLARY
#
#                                   Premise Description Victim Descent  \
# 1239698                                        STREET              W
# 1186339                                    LAUNDROMAT              K
# 687145   MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)              H
# 1497089                                        STREET              W
# 896171                         SINGLE FAMILY DWELLING              H
# ...                                               ...            ...
# 527661   MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)              W
# 1005879                  PARKING UNDERGROUND/BUILDING              H
# 618143                                         STREET              B
# 165255                         SINGLE FAMILY DWELLING              B
# 131799                         SINGLE FAMILY DWELLING              A
#
#         Victim Sex  Days Between
# 1239698          F             5
# 1186339          M             1
# 687145           F             8
# 1497089          F             0
# 896171           M             0
# ...            ...           ...
# 527661           M             1
# 1005879          M             0
# 618143           F            31
# 165255           F             0
# 131799           F             2
#
# [347325 rows x 12 columns]
# array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 3.05166426e-04],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 2.44102609e-04],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 1.96930810e-05],
#        ...,
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 2.46392502e-04],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 1.55560074e-04],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 1.52506883e-04]])

# %%
def model_build(hp):
    hyper_model=Sequential()
    #units=hp.Int('units',min_value=8,max_value=138,step=16)
    units=hp.Choice('units',[8,16,64,128,256,512])
    drop=hp.Choice('dropout',[0.1,0.2,0.3,0.4])
    #lr=hp.Choice('learning_rate',[10**(-3),10**(-4),10**(-5)])
    #depth=hp.Int('depth',min_value=3,max_value=8,step=1)
    depth=hp.Choice('depth',[3,4,5,6,7,8])
    batch=hp.Choice('Batch Normalization',[0,1])
    hyper_model.add(Dense(units=units, activation='elu', input_dim=1644))
    hyper_model.add(Dropout(drop))
    if batch==1:
        hyper_model.add(tf.keras.layers.BatchNormalization())
    for i in range(depth):
        if units>4:
            units=int(units/2)
        hyper_model.add(Dense(units=units, activation='elu'))
        hyper_model.add(Dropout(drop))
        if batch==1:
            hyper_model.add(tf.keras.layers.BatchNormalization())
    hyper_model.add(Dense(units=1, activation='sigmoid'))
    hyper_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=5*10**(-6)),loss='binary_crossentropy',metrics=['accuracy','precision','AUC'])
    return hyper_model

# %%
hp_tuner=kt.RandomSearch(model_build,objective='val_AUC',max_trials=25,project_name='Tuning_batch_RandomSearch_halved2')
hp_tuner.search(Code_embed,np.array(Y_train_embed),validation_split=0.3,epochs=5,batch_size=64,class_weight=class_weight_dict_embed,callbacks=[tf.keras.callbacks.TensorBoard(log_dir='RandomSearch_halved_tuning2/logs')])
# Out:
# Trial 25 Complete [00h 05m 04s]
# val_AUC: 0.8118925094604492
#
# Best val_AUC So Far: 0.8216362595558167
# Total elapsed time: 00h 47m 23s

# %%
best_params=hp_tuner.get_best_hyperparameters(num_trials=1)[0]

# %%
model_optimized=Sequential()
#model_optimized.add(Dense(units=104, activation='elu', input_dim=1643))
#model_optimized.add(Dense(units=104, activation='elu'))
#model_optimized.add(Dropout(0.1))
#model_optimized.add(Dense(units=104, activation='elu'))
#model_optimized.add(Dropout(0.1))
#model_optimized.add(Dense(units=104, activation='elu'))
#model_optimized.add(Dropout(0.1))
#model_optimized.add(Dense(units=104, activation='elu'))
#model_optimized.add(Dropout(0.1))
#model_optimized.add(Dense(units=1, activation='sigmoid'))
model_optimized.add(Dense(units=256, activation='elu', input_dim=1644))
model_optimized.add(Dropout(0.2))
model_optimized.add(tf.keras.layers.BatchNormalization())
model_optimized.add(Dense(units=128, activation='elu'))
model_optimized.add(Dropout(0.1))
model_optimized.add(tf.keras.layers.BatchNormalization())
model_optimized.add(Dense(units=64, activation='elu'))
model_optimized.add(Dropout(0.1))
model_optimized.add(tf.keras.layers.BatchNormalization())
model_optimized.add(Dense(units=32, activation='elu'))
model_optimized.add(Dropout(0.1))
model_optimized.add(tf.keras.layers.BatchNormalization())
#model_optimized.add(Dense(units=256, activation='elu'))
#model_optimized.add(Dropout(0.2))
#model_optimized.add(tf.keras.layers.BatchNormalization())
#model_optimized.add(Dense(units=256, activation='elu'))
#model_optimized.add(Dropout(0.1))
model_optimized.add(Dense(units=1, activation='sigmoid'))
model_optimized.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=5*10**(-6)),loss='binary_crossentropy',metrics=['accuracy','precision','AUC'])
# Out:
# /Users/leanderflottau/miniforge3/envs/IceCube/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#optimized_hist=model_optimized.fit(Code_embed,np.array(Y_train_embed),validation_split=0.3,epochs=40,batch_size=64,class_weight=class_weight_dict_embed,callbacks=[HistoryEpoch((Code_embed,np.array(Y_train_embed)))])
optimized_hist=model_optimized.fit(Code_embed_train,np.array(Y_embed_train),validation_data=(Code_embed_val,np.array(Y_embed_val)),epochs=35,batch_size=64,class_weight=class_weight_dict_embed,callbacks=[HistoryEpoch((Code_embed_train,np.array(Y_embed_train)))])
# Out:
# Epoch 1/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 32s 4ms/step - AUC: 0.6266 - accuracy: 0.5428 - loss: 0.7134 - precision: 0.1681 - val_AUC: 0.7902 - val_accuracy: 0.6270 - val_loss: 0.6877 - val_precision: 0.2306 - train_loss: 0.6891 - train_accuracy: 0.6260 - train_precision: 0.2311 - train_AUC: 0.7917
# Epoch 2/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 30s 3ms/step - AUC: 0.7531 - accuracy: 0.6370 - loss: 0.6015 - precision: 0.2249 - val_AUC: 0.8048 - val_accuracy: 0.6763 - val_loss: 0.6265 - val_precision: 0.2555 - train_loss: 0.6271 - train_accuracy: 0.6755 - train_precision: 0.2558 - train_AUC: 0.8071
# Epoch 3/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 30s 3ms/step - AUC: 0.7734 - accuracy: 0.6764 - loss: 0.5786 - precision: 0.2472 - val_AUC: 0.8111 - val_accuracy: 0.6962 - val_loss: 0.5961 - val_precision: 0.2671 - train_loss: 0.5963 - train_accuracy: 0.6958 - train_precision: 0.2676 - train_AUC: 0.8139
# Epoch 4/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 30s 3ms/step - AUC: 0.7837 - accuracy: 0.6962 - loss: 0.5662 - precision: 0.2595 - val_AUC: 0.8147 - val_accuracy: 0.7086 - val_loss: 0.5759 - val_precision: 0.2749 - train_loss: 0.5755 - train_accuracy: 0.7081 - train_precision: 0.2754 - train_AUC: 0.8181
# Epoch 5/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 30s 3ms/step - AUC: 0.7922 - accuracy: 0.7080 - loss: 0.5566 - precision: 0.2686 - val_AUC: 0.8173 - val_accuracy: 0.7137 - val_loss: 0.5656 - val_precision: 0.2783 - train_loss: 0.5649 - train_accuracy: 0.7136 - train_precision: 0.2793 - train_AUC: 0.8211
# Epoch 6/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 30s 3ms/step - AUC: 0.7945 - accuracy: 0.7133 - loss: 0.5533 - precision: 0.2722 - val_AUC: 0.8192 - val_accuracy: 0.7245 - val_loss: 0.5506 - val_precision: 0.2856 - train_loss: 0.5495 - train_accuracy: 0.7242 - train_precision: 0.2865 - train_AUC: 0.8234
# Epoch 7/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 30s 3ms/step - AUC: 0.8009 - accuracy: 0.7195 - loss: 0.5461 - precision: 0.2777 - val_AUC: 0.8206 - val_accuracy: 0.7233 - val_loss: 0.5498 - val_precision: 0.2851 - train_loss: 0.5485 - train_accuracy: 0.7237 - train_precision: 0.2866 - train_AUC: 0.8252
# Epoch 8/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 30s 3ms/step - AUC: 0.8030 - accuracy: 0.7226 - loss: 0.5417 - precision: 0.2785 - val_AUC: 0.8218 - val_accuracy: 0.7254 - val_loss: 0.5466 - val_precision: 0.2868 - train_loss: 0.5452 - train_accuracy: 0.7257 - train_precision: 0.2885 - train_AUC: 0.8266
# Epoch 9/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 30s 3ms/step - AUC: 0.8047 - accuracy: 0.7254 - loss: 0.5395 - precision: 0.2809 - val_AUC: 0.8230 - val_accuracy: 0.7305 - val_loss: 0.5387 - val_precision: 0.2905 - train_loss: 0.5370 - train_accuracy: 0.7309 - train_precision: 0.2923 - train_AUC: 0.8280
# Epoch 10/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 30s 3ms/step - AUC: 0.8072 - accuracy: 0.7284 - loss: 0.5364 - precision: 0.2836 - val_AUC: 0.8238 - val_accuracy: 0.7295 - val_loss: 0.5385 - val_precision: 0.2902 - train_loss: 0.5366 - train_accuracy: 0.7299 - train_precision: 0.2922 - train_AUC: 0.8291
# Epoch 11/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 51s 6ms/step - AUC: 0.8095 - accuracy: 0.7278 - loss: 0.5351 - precision: 0.2851 - val_AUC: 0.8247 - val_accuracy: 0.7346 - val_loss: 0.5319 - val_precision: 0.2939 - train_loss: 0.5299 - train_accuracy: 0.7351 - train_precision: 0.2959 - train_AUC: 0.8303
# Epoch 12/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 30s 3ms/step - AUC: 0.8105 - accuracy: 0.7301 - loss: 0.5313 - precision: 0.2845 - val_AUC: 0.8254 - val_accuracy: 0.7332 - val_loss: 0.5345 - val_precision: 0.2934 - train_loss: 0.5323 - train_accuracy: 0.7339 - train_precision: 0.2956 - train_AUC: 0.8312
# Epoch 13/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 30s 3ms/step - AUC: 0.8113 - accuracy: 0.7310 - loss: 0.5331 - precision: 0.2885 - val_AUC: 0.8261 - val_accuracy: 0.7383 - val_loss: 0.5274 - val_precision: 0.2971 - train_loss: 0.5250 - train_accuracy: 0.7390 - train_precision: 0.2994 - train_AUC: 0.8322
# Epoch 14/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 30s 3ms/step - AUC: 0.8145 - accuracy: 0.7328 - loss: 0.5277 - precision: 0.2887 - val_AUC: 0.8267 - val_accuracy: 0.7363 - val_loss: 0.5278 - val_precision: 0.2960 - train_loss: 0.5253 - train_accuracy: 0.7369 - train_precision: 0.2981 - train_AUC: 0.8330
# Epoch 15/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 30s 3ms/step - AUC: 0.8167 - accuracy: 0.7335 - loss: 0.5257 - precision: 0.2906 - val_AUC: 0.8273 - val_accuracy: 0.7392 - val_loss: 0.5254 - val_precision: 0.2982 - train_loss: 0.5227 - train_accuracy: 0.7401 - train_precision: 0.3008 - train_AUC: 0.8338
# Epoch 16/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 30s 3ms/step - AUC: 0.8154 - accuracy: 0.7353 - loss: 0.5274 - precision: 0.2922 - val_AUC: 0.8277 - val_accuracy: 0.7400 - val_loss: 0.5247 - val_precision: 0.2988 - train_loss: 0.5220 - train_accuracy: 0.7410 - train_precision: 0.3014 - train_AUC: 0.8345
# Epoch 17/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 30s 3ms/step - AUC: 0.8171 - accuracy: 0.7368 - loss: 0.5257 - precision: 0.2941 - val_AUC: 0.8281 - val_accuracy: 0.7412 - val_loss: 0.5212 - val_precision: 0.2998 - train_loss: 0.5183 - train_accuracy: 0.7421 - train_precision: 0.3024 - train_AUC: 0.8351
# Epoch 18/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 30s 3ms/step - AUC: 0.8181 - accuracy: 0.7374 - loss: 0.5242 - precision: 0.2946 - val_AUC: 0.8285 - val_accuracy: 0.7442 - val_loss: 0.5176 - val_precision: 0.3023 - train_loss: 0.5144 - train_accuracy: 0.7450 - train_precision: 0.3046 - train_AUC: 0.8357
# Epoch 19/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 31s 4ms/step - AUC: 0.8201 - accuracy: 0.7378 - loss: 0.5208 - precision: 0.2944 - val_AUC: 0.8288 - val_accuracy: 0.7415 - val_loss: 0.5218 - val_precision: 0.3002 - train_loss: 0.5185 - train_accuracy: 0.7428 - train_precision: 0.3033 - train_AUC: 0.8362
# Epoch 20/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 34s 4ms/step - AUC: 0.8205 - accuracy: 0.7387 - loss: 0.5196 - precision: 0.2943 - val_AUC: 0.8291 - val_accuracy: 0.7474 - val_loss: 0.5133 - val_precision: 0.3049 - train_loss: 0.5098 - train_accuracy: 0.7482 - train_precision: 0.3074 - train_AUC: 0.8368
# Epoch 21/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 34s 4ms/step - AUC: 0.8220 - accuracy: 0.7396 - loss: 0.5195 - precision: 0.2976 - val_AUC: 0.8295 - val_accuracy: 0.7472 - val_loss: 0.5129 - val_precision: 0.3048 - train_loss: 0.5093 - train_accuracy: 0.7481 - train_precision: 0.3074 - train_AUC: 0.8373
# Epoch 22/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 33s 4ms/step - AUC: 0.8210 - accuracy: 0.7401 - loss: 0.5206 - precision: 0.2977 - val_AUC: 0.8298 - val_accuracy: 0.7455 - val_loss: 0.5163 - val_precision: 0.3036 - train_loss: 0.5126 - train_accuracy: 0.7464 - train_precision: 0.3063 - train_AUC: 0.8378
# Epoch 23/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 32s 4ms/step - AUC: 0.8210 - accuracy: 0.7399 - loss: 0.5211 - precision: 0.2979 - val_AUC: 0.8300 - val_accuracy: 0.7499 - val_loss: 0.5092 - val_precision: 0.3070 - train_loss: 0.5054 - train_accuracy: 0.7509 - train_precision: 0.3098 - train_AUC: 0.8383
# Epoch 24/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 32s 4ms/step - AUC: 0.8243 - accuracy: 0.7426 - loss: 0.5171 - precision: 0.3010 - val_AUC: 0.8302 - val_accuracy: 0.7478 - val_loss: 0.5148 - val_precision: 0.3054 - train_loss: 0.5108 - train_accuracy: 0.7489 - train_precision: 0.3085 - train_AUC: 0.8388
# Epoch 25/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 33s 4ms/step - AUC: 0.8239 - accuracy: 0.7415 - loss: 0.5168 - precision: 0.2987 - val_AUC: 0.8305 - val_accuracy: 0.7451 - val_loss: 0.5175 - val_precision: 0.3033 - train_loss: 0.5134 - train_accuracy: 0.7463 - train_precision: 0.3066 - train_AUC: 0.8392
# Epoch 26/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 33s 4ms/step - AUC: 0.8246 - accuracy: 0.7426 - loss: 0.5164 - precision: 0.3007 - val_AUC: 0.8307 - val_accuracy: 0.7526 - val_loss: 0.5076 - val_precision: 0.3093 - train_loss: 0.5032 - train_accuracy: 0.7536 - train_precision: 0.3123 - train_AUC: 0.8396
# Epoch 27/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 33s 4ms/step - AUC: 0.8246 - accuracy: 0.7439 - loss: 0.5153 - precision: 0.3008 - val_AUC: 0.8308 - val_accuracy: 0.7507 - val_loss: 0.5109 - val_precision: 0.3078 - train_loss: 0.5065 - train_accuracy: 0.7520 - train_precision: 0.3113 - train_AUC: 0.8399
# Epoch 28/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 33s 4ms/step - AUC: 0.8260 - accuracy: 0.7445 - loss: 0.5137 - precision: 0.3014 - val_AUC: 0.8311 - val_accuracy: 0.7512 - val_loss: 0.5079 - val_precision: 0.3082 - train_loss: 0.5034 - train_accuracy: 0.7524 - train_precision: 0.3115 - train_AUC: 0.8404
# Epoch 29/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 33s 4ms/step - AUC: 0.8273 - accuracy: 0.7447 - loss: 0.5117 - precision: 0.3019 - val_AUC: 0.8313 - val_accuracy: 0.7485 - val_loss: 0.5108 - val_precision: 0.3060 - train_loss: 0.5062 - train_accuracy: 0.7501 - train_precision: 0.3100 - train_AUC: 0.8407
# Epoch 30/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 33s 4ms/step - AUC: 0.8252 - accuracy: 0.7431 - loss: 0.5148 - precision: 0.3004 - val_AUC: 0.8315 - val_accuracy: 0.7470 - val_loss: 0.5159 - val_precision: 0.3051 - train_loss: 0.5112 - train_accuracy: 0.7486 - train_precision: 0.3090 - train_AUC: 0.8411
# Epoch 31/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 33s 4ms/step - AUC: 0.8278 - accuracy: 0.7445 - loss: 0.5113 - precision: 0.3017 - val_AUC: 0.8316 - val_accuracy: 0.7542 - val_loss: 0.5060 - val_precision: 0.3105 - train_loss: 0.5010 - train_accuracy: 0.7559 - train_precision: 0.3146 - train_AUC: 0.8415
# Epoch 32/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 33s 4ms/step - AUC: 0.8277 - accuracy: 0.7455 - loss: 0.5116 - precision: 0.3030 - val_AUC: 0.8318 - val_accuracy: 0.7506 - val_loss: 0.5112 - val_precision: 0.3078 - train_loss: 0.5062 - train_accuracy: 0.7524 - train_precision: 0.3120 - train_AUC: 0.8419
# Epoch 33/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 33s 4ms/step - AUC: 0.8281 - accuracy: 0.7473 - loss: 0.5112 - precision: 0.3046 - val_AUC: 0.8319 - val_accuracy: 0.7482 - val_loss: 0.5107 - val_precision: 0.3060 - train_loss: 0.5056 - train_accuracy: 0.7502 - train_precision: 0.3104 - train_AUC: 0.8421
# Epoch 34/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 33s 4ms/step - AUC: 0.8288 - accuracy: 0.7459 - loss: 0.5111 - precision: 0.3044 - val_AUC: 0.8320 - val_accuracy: 0.7501 - val_loss: 0.5115 - val_precision: 0.3075 - train_loss: 0.5061 - train_accuracy: 0.7521 - train_precision: 0.3120 - train_AUC: 0.8425
# Epoch 35/35
# 8864/8864 ━━━━━━━━━━━━━━━━━━━━ 34s 4ms/step - AUC: 0.8285 - accuracy: 0.7465 - loss: 0.5099 - precision: 0.3029 - val_AUC: 0.8321 - val_accuracy: 0.7512 - val_loss: 0.5107 - val_precision: 0.3083 - train_loss: 0.5052 - train_accuracy: 0.7532 - train_precision: 0.3130 - train_AUC: 0.8429

# %%
optimized_pred=model_optimized.predict(Onehot_test)
randomized_pred=model_optimized.predict(test_random_ages)
roc_auc_score(Y_test_embed,optimized_pred)
# Out:
# 10854/10854 ━━━━━━━━━━━━━━━━━━━━ 5s 441us/step
# 10854/10854 ━━━━━━━━━━━━━━━━━━━━ 5s 428us/step
# 0.8328133949801726

# %%
model_optimized.evaluate(Onehot_test,np.array(Y_test_embed))
# Out:
# 10854/10854 ━━━━━━━━━━━━━━━━━━━━ 5s 498us/step - AUC: 0.8326 - accuracy: 0.7489 - loss: 0.5128 - precision: 0.3051
# [0.5128933787345886,
#  0.7491945624351501,
#  0.30629897117614746,
#  0.8328064680099487]

# %%
plt.hist2d((X_test_random['Victim Age'])[Y_test_embed==0],(randomized_pred[:,0])[Y_test_embed==0],bins=99,norm='log')
plt.colorbar()
plt.ylabel('prediction')
plt.xlabel('Age')
plt.show()
plt.hist2d((X_test_random['Victim Age'])[Y_test_embed==1],(randomized_pred[:,0])[Y_test_embed==1],bins=99,norm='log')
plt.colorbar()
plt.ylabel('prediction')
plt.xlabel('Age')
plt.show()
plt.hist2d((X_test_random['Victim Age']),(randomized_pred[:,0]),bins=99,norm='log')
plt.colorbar()
plt.ylabel('prediction')
plt.xlabel('Age')
#plt.hist2d((X_test_random['Victim Age'])[Y_test_embed==0],(predict_proba[:,1])[Y_test_embed==0],bins=99,norm='log')
# Out:
# Text(0.5, 0, 'Age')

# %%
#plt.plot(range(20),embed_hist.history['val_AUC'],label='high lr AUC validation')
#plt.plot(range(20),embed_hist.history['AUC'],label='high lr AUC test')
plt.plot(range(35),optimized_hist.history['val_AUC'],label='validation')
plt.plot(range(35),optimized_hist.history['train_AUC'],label='training')
plt.xlabel('epoch')
plt.ylabel('AUC')
plt.legend()

# %%
plt.plot(range(35),optimized_hist.history['val_loss'],label='validation')
plt.plot(range(35),optimized_hist.history['train_loss'],label='training (no dropout)')
plt.plot(range(35),optimized_hist.history['loss'],label='training (dropout)')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()

# %%
plt.hist(optimized_pred[Y_test_embed==0],bins=30,histtype='step',label='no arrest')
plt.hist(optimized_pred[Y_test_embed==1],bins=30,histtype='step',label='arrest')
plt.xlabel('prediction')
plt.ylabel('counts')
plt.yscale('log')
plt.legend()

# %%
tpr_oh,fpr_oh,th_oh=roc_curve(Y_test_embed,optimized_pred)
plt.plot(tpr_oh,fpr_oh,label='DNN')
plt.plot(tpr,fpr,label='Random Forest')
plt.plot(tpr_HGC,fpr_HGC,label='HistGradient')
print(roc_auc_score(Y_test_embed,optimized_pred))
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.legend()
# Out:
# 0.8328133949801726

# %%
tpr_oh,fpr_oh,th_oh=roc_curve(Y_test_embed,optimized_pred)
plt.plot(tpr_oh,fpr_oh,label='DNN')
plt.plot(tpr,fpr,label='Random Forest')
#plt.plot(tpr_HGC,fpr_HGC,label='HistGradient')
print(roc_auc_score(Y_test_embed,optimized_pred))
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.legend()
# Out:
# 0.8328374338547776

# %%
# Assuming embed_hist.history is a dictionary containing the training history
history_dataframe = optimized_hist.history

# Create a DataFrame from the history dictionary
df = pd.DataFrame(history_dataframe)

# Create subplots
fig, ax = plt.subplots(2, 1, figsize=(8, 10))

# Plot the loss curves in the first subplot
df[['train_loss', 'val_loss']].plot(
    ax=ax[0],
    xlim=[0, 34], 
    ylim=[0, 1], 
    grid=True, 
    ylabel = "loss",
    xlabel="Epoch",
    style=["r--", "b--."]
)
ax[0].set_title('Training and Validation Loss')

# Plot the other metrics (e.g., accuracy, precision, AUC) in the second subplot
df[['train_accuracy', 'val_accuracy', 'train_precision', 'val_precision', 'train_AUC', 'val_AUC']].plot(
    ax=ax[1],
    xlim=[0, 34], 
    ylim=[0, 1], 
    grid=True, 
    xlabel="Epoch",
    style=["b-", "b-", "g--", "g--", "m-", "m-*"]
)
ax[1].set_title('Training and Validation Metrics')

# Display the plots
plt.tight_layout()
plt.show()

# %%
history = optimized_hist.history
df = pd.DataFrame(history)

df[['train_accuracy', 'val_accuracy', 'train_loss', 'val_loss']].plot(
    figsize=(8, 5), xlim=[0, 34], ylim=[0, 1], grid=True, xlabel="Epoch",
    style=["r--", "r--.", "b-", "b-*"], title="Training and Validation Accuracy and Loss"
)
plt.show()

# %%
uniques=np.array([len(set(merged_embed['Crime Code Description'])),len(set(merged_embed['Premise Description'])),len(set(merged_embed['Victim Sex'])),len(set(merged_embed['Victim Descent'])),len(set(merged_embed['Area ID'])),len(set(merged_embed['Reporting District']))])
categoricals=['Crime','Premise','Vict. Sex','Vict. Descent','Area ID','District']
plt.bar(categoricals,uniques)
plt.xlabel('Feature')
plt.ylabel('Number of unique categories')
plt.yscale('log')
plt.savefig('Unique_Categories.pdf')

# %%
len(set(merged_embed['Reporting District']))
# Out:
# 1253

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.utils import shuffle
skf=StratifiedKFold(n_splits=4,shuffle=True)
AUC=np.zeros((4,2))
#acc=np.zeros((4,2))
train_loss=np.zeros((4,15))
val_loss=np.zeros((4,15))
train_AUC=np.zeros((4,15))
val_AUC=np.zeros((4,15))
merged_shuffled=shuffle(merged_embed)
X_cv=merged_shuffled.drop('arrest',axis=1)
Y_cv=merged_shuffled['arrest']
#print(X_cv.head())
for k_index, (train_idx, test_idx) in enumerate(skf.split(X,Y)):
    #print(k_index)
    x_cv_train=X_cv.iloc[train_idx]
    x_cv_test=X_cv.iloc[test_idx]
    y_cv_train=Y_cv.iloc[train_idx]
    y_cv_test=Y_cv.iloc[test_idx]
    #print(x_cv_train)
    class_weights_cv=compute_class_weight(class_weight='balanced',classes=np.unique(y_cv_train),y=y_cv_train)
    class_weight_cv = dict(enumerate(class_weights_cv))
    #print(x_cv_train)
    x_cv_train,x_cv_test=set_features(x_cv_train,x_cv_test)
    #print(class_weight_cv)
    #print(x_cv_train)
    #print(np.array(y_cv_test))
    model_cv=Sequential()
    model_cv.add(Dense(units=256, activation='elu', input_dim=1644))
    model_cv.add(Dropout(0.2))
    model_cv.add(tf.keras.layers.BatchNormalization())
    model_cv.add(Dense(units=128, activation='elu', input_dim=1644))
    model_cv.add(Dropout(0.2))
    model_cv.add(tf.keras.layers.BatchNormalization())
    model_cv.add(Dense(units=64, activation='elu', input_dim=1644))
    model_cv.add(Dropout(0.2))
    model_cv.add(tf.keras.layers.BatchNormalization())
    model_cv.add(Dense(units=32, activation='elu', input_dim=1644))
    model_cv.add(Dropout(0.2))
    model_cv.add(tf.keras.layers.BatchNormalization())
    model_cv.add(Dense(units=1, activation='sigmoid'))
    model_cv.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=5*10**(-6)),loss='binary_crossentropy',metrics=['accuracy','precision','AUC'])
    cv_history=model_cv.fit(x_cv_train,np.array(y_cv_train),validation_split=0.3,epochs=15,batch_size=64,class_weight=class_weight_cv,callbacks=[HistoryEpoch((x_cv_train,np.array(y_cv_train)))])
    cv_pred=model_cv.predict(x_cv_test)
    AUC[k_index,0]=roc_auc_score(y_cv_test,cv_pred)
    AUC[k_index,1]=(cv_history.history['train_AUC'])[-1]
    train_loss[k_index,:]=cv_history.history['loss'] 
    val_loss[k_index,:]=cv_history.history['val_loss']
    train_AUC[k_index,:]=cv_history.history['AUC']
    val_AUC[k_index,:]=cv_history.history['val_AUC']
# Out:
# /Users/leanderflottau/miniforge3/envs/IceCube/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 39s 4ms/step - AUC: 0.5999 - accuracy: 0.5369 - loss: 0.7726 - precision: 0.1599 - val_AUC: 0.7904 - val_accuracy: 0.6773 - val_loss: 0.6270 - val_precision: 0.2512 - train_loss: 0.6273 - train_accuracy: 0.6767 - train_precision: 0.2519 - train_AUC: 0.7917
# Epoch 2/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 37s 4ms/step - AUC: 0.7311 - accuracy: 0.6266 - loss: 0.6338 - precision: 0.2147 - val_AUC: 0.8039 - val_accuracy: 0.7033 - val_loss: 0.5870 - val_precision: 0.2680 - train_loss: 0.5869 - train_accuracy: 0.7034 - train_precision: 0.2694 - train_AUC: 0.8059
# Epoch 3/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 37s 4ms/step - AUC: 0.7565 - accuracy: 0.6633 - loss: 0.6018 - precision: 0.2346 - val_AUC: 0.8096 - val_accuracy: 0.7179 - val_loss: 0.5596 - val_precision: 0.2779 - train_loss: 0.5593 - train_accuracy: 0.7179 - train_precision: 0.2794 - train_AUC: 0.8120
# Epoch 4/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 38s 4ms/step - AUC: 0.7685 - accuracy: 0.6809 - loss: 0.5879 - precision: 0.2469 - val_AUC: 0.8131 - val_accuracy: 0.7229 - val_loss: 0.5501 - val_precision: 0.2818 - train_loss: 0.5496 - train_accuracy: 0.7229 - train_precision: 0.2833 - train_AUC: 0.8159
# Epoch 5/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 38s 4ms/step - AUC: 0.7764 - accuracy: 0.6944 - loss: 0.5780 - precision: 0.2563 - val_AUC: 0.8153 - val_accuracy: 0.7281 - val_loss: 0.5389 - val_precision: 0.2857 - train_loss: 0.5382 - train_accuracy: 0.7281 - train_precision: 0.2873 - train_AUC: 0.8185
# Epoch 6/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 38s 4ms/step - AUC: 0.7840 - accuracy: 0.7014 - loss: 0.5686 - precision: 0.2619 - val_AUC: 0.8172 - val_accuracy: 0.7310 - val_loss: 0.5317 - val_precision: 0.2881 - train_loss: 0.5308 - train_accuracy: 0.7311 - train_precision: 0.2898 - train_AUC: 0.8205
# Epoch 7/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 38s 4ms/step - AUC: 0.7905 - accuracy: 0.7073 - loss: 0.5603 - precision: 0.2667 - val_AUC: 0.8186 - val_accuracy: 0.7333 - val_loss: 0.5277 - val_precision: 0.2899 - train_loss: 0.5267 - train_accuracy: 0.7336 - train_precision: 0.2919 - train_AUC: 0.8222
# Epoch 8/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 39s 4ms/step - AUC: 0.7944 - accuracy: 0.7125 - loss: 0.5562 - precision: 0.2724 - val_AUC: 0.8197 - val_accuracy: 0.7341 - val_loss: 0.5258 - val_precision: 0.2908 - train_loss: 0.5246 - train_accuracy: 0.7346 - train_precision: 0.2930 - train_AUC: 0.8236
# Epoch 9/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 38s 4ms/step - AUC: 0.7965 - accuracy: 0.7148 - loss: 0.5524 - precision: 0.2732 - val_AUC: 0.8206 - val_accuracy: 0.7370 - val_loss: 0.5218 - val_precision: 0.2932 - train_loss: 0.5205 - train_accuracy: 0.7373 - train_precision: 0.2953 - train_AUC: 0.8247
# Epoch 10/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 40s 4ms/step - AUC: 0.7983 - accuracy: 0.7164 - loss: 0.5508 - precision: 0.2748 - val_AUC: 0.8214 - val_accuracy: 0.7385 - val_loss: 0.5184 - val_precision: 0.2946 - train_loss: 0.5170 - train_accuracy: 0.7390 - train_precision: 0.2969 - train_AUC: 0.8256
# Epoch 11/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 45s 5ms/step - AUC: 0.8022 - accuracy: 0.7197 - loss: 0.5460 - precision: 0.2784 - val_AUC: 0.8221 - val_accuracy: 0.7369 - val_loss: 0.5205 - val_precision: 0.2937 - train_loss: 0.5190 - train_accuracy: 0.7374 - train_precision: 0.2960 - train_AUC: 0.8265
# Epoch 12/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 43s 4ms/step - AUC: 0.8057 - accuracy: 0.7222 - loss: 0.5406 - precision: 0.2798 - val_AUC: 0.8228 - val_accuracy: 0.7377 - val_loss: 0.5221 - val_precision: 0.2945 - train_loss: 0.5205 - train_accuracy: 0.7384 - train_precision: 0.2971 - train_AUC: 0.8273
# Epoch 13/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - AUC: 0.8070 - accuracy: 0.7232 - loss: 0.5396 - precision: 0.2815 - val_AUC: 0.8233 - val_accuracy: 0.7387 - val_loss: 0.5197 - val_precision: 0.2953 - train_loss: 0.5181 - train_accuracy: 0.7392 - train_precision: 0.2978 - train_AUC: 0.8279
# Epoch 14/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - AUC: 0.8047 - accuracy: 0.7237 - loss: 0.5422 - precision: 0.2814 - val_AUC: 0.8239 - val_accuracy: 0.7406 - val_loss: 0.5177 - val_precision: 0.2970 - train_loss: 0.5160 - train_accuracy: 0.7412 - train_precision: 0.2994 - train_AUC: 0.8286
# Epoch 15/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - AUC: 0.8098 - accuracy: 0.7259 - loss: 0.5358 - precision: 0.2844 - val_AUC: 0.8243 - val_accuracy: 0.7415 - val_loss: 0.5150 - val_precision: 0.2978 - train_loss: 0.5132 - train_accuracy: 0.7422 - train_precision: 0.3003 - train_AUC: 0.8293
# 9045/9045 ━━━━━━━━━━━━━━━━━━━━ 4s 458us/step
# /Users/leanderflottau/miniforge3/envs/IceCube/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - AUC: 0.6234 - accuracy: 0.5484 - loss: 0.7505 - precision: 0.1675 - val_AUC: 0.7895 - val_accuracy: 0.6676 - val_loss: 0.6459 - val_precision: 0.2475 - train_loss: 0.6453 - train_accuracy: 0.6681 - train_precision: 0.2481 - train_AUC: 0.7907
# Epoch 2/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 44s 5ms/step - AUC: 0.7301 - accuracy: 0.6325 - loss: 0.6374 - precision: 0.2171 - val_AUC: 0.8030 - val_accuracy: 0.6991 - val_loss: 0.6023 - val_precision: 0.2670 - train_loss: 0.6017 - train_accuracy: 0.6991 - train_precision: 0.2674 - train_AUC: 0.8045
# Epoch 3/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 44s 5ms/step - AUC: 0.7532 - accuracy: 0.6679 - loss: 0.6084 - precision: 0.2372 - val_AUC: 0.8094 - val_accuracy: 0.7187 - val_loss: 0.5687 - val_precision: 0.2799 - train_loss: 0.5682 - train_accuracy: 0.7183 - train_precision: 0.2800 - train_AUC: 0.8112
# Epoch 4/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 43s 5ms/step - AUC: 0.7663 - accuracy: 0.6865 - loss: 0.5923 - precision: 0.2493 - val_AUC: 0.8130 - val_accuracy: 0.7172 - val_loss: 0.5698 - val_precision: 0.2797 - train_loss: 0.5693 - train_accuracy: 0.7170 - train_precision: 0.2800 - train_AUC: 0.8150
# Epoch 5/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 44s 5ms/step - AUC: 0.7741 - accuracy: 0.6982 - loss: 0.5820 - precision: 0.2578 - val_AUC: 0.8156 - val_accuracy: 0.7265 - val_loss: 0.5508 - val_precision: 0.2862 - train_loss: 0.5502 - train_accuracy: 0.7264 - train_precision: 0.2865 - train_AUC: 0.8177
# Epoch 6/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 43s 5ms/step - AUC: 0.7799 - accuracy: 0.7049 - loss: 0.5735 - precision: 0.2622 - val_AUC: 0.8174 - val_accuracy: 0.7260 - val_loss: 0.5488 - val_precision: 0.2861 - train_loss: 0.5482 - train_accuracy: 0.7262 - train_precision: 0.2868 - train_AUC: 0.8196
# Epoch 7/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 44s 5ms/step - AUC: 0.7874 - accuracy: 0.7115 - loss: 0.5658 - precision: 0.2698 - val_AUC: 0.8188 - val_accuracy: 0.7298 - val_loss: 0.5408 - val_precision: 0.2889 - train_loss: 0.5400 - train_accuracy: 0.7298 - train_precision: 0.2894 - train_AUC: 0.8212
# Epoch 8/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 43s 5ms/step - AUC: 0.7876 - accuracy: 0.7119 - loss: 0.5644 - precision: 0.2689 - val_AUC: 0.8201 - val_accuracy: 0.7281 - val_loss: 0.5412 - val_precision: 0.2883 - train_loss: 0.5404 - train_accuracy: 0.7280 - train_precision: 0.2887 - train_AUC: 0.8226
# Epoch 9/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 45s 5ms/step - AUC: 0.7931 - accuracy: 0.7156 - loss: 0.5575 - precision: 0.2726 - val_AUC: 0.8211 - val_accuracy: 0.7255 - val_loss: 0.5435 - val_precision: 0.2869 - train_loss: 0.5427 - train_accuracy: 0.7255 - train_precision: 0.2874 - train_AUC: 0.8236
# Epoch 10/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 43s 5ms/step - AUC: 0.7971 - accuracy: 0.7184 - loss: 0.5541 - precision: 0.2773 - val_AUC: 0.8219 - val_accuracy: 0.7354 - val_loss: 0.5280 - val_precision: 0.2936 - train_loss: 0.5271 - train_accuracy: 0.7354 - train_precision: 0.2942 - train_AUC: 0.8247
# Epoch 11/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 44s 5ms/step - AUC: 0.7998 - accuracy: 0.7214 - loss: 0.5487 - precision: 0.2784 - val_AUC: 0.8227 - val_accuracy: 0.7407 - val_loss: 0.5209 - val_precision: 0.2976 - train_loss: 0.5198 - train_accuracy: 0.7407 - train_precision: 0.2983 - train_AUC: 0.8256
# Epoch 12/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 45s 5ms/step - AUC: 0.8010 - accuracy: 0.7228 - loss: 0.5476 - precision: 0.2798 - val_AUC: 0.8234 - val_accuracy: 0.7387 - val_loss: 0.5225 - val_precision: 0.2965 - train_loss: 0.5215 - train_accuracy: 0.7388 - train_precision: 0.2973 - train_AUC: 0.8263
# Epoch 13/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 44s 5ms/step - AUC: 0.8030 - accuracy: 0.7238 - loss: 0.5445 - precision: 0.2807 - val_AUC: 0.8240 - val_accuracy: 0.7342 - val_loss: 0.5312 - val_precision: 0.2939 - train_loss: 0.5301 - train_accuracy: 0.7340 - train_precision: 0.2944 - train_AUC: 0.8270
# Epoch 14/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 43s 5ms/step - AUC: 0.8057 - accuracy: 0.7256 - loss: 0.5412 - precision: 0.2832 - val_AUC: 0.8246 - val_accuracy: 0.7344 - val_loss: 0.5310 - val_precision: 0.2944 - train_loss: 0.5298 - train_accuracy: 0.7343 - train_precision: 0.2949 - train_AUC: 0.8277
# Epoch 15/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 45s 5ms/step - AUC: 0.8044 - accuracy: 0.7265 - loss: 0.5425 - precision: 0.2831 - val_AUC: 0.8250 - val_accuracy: 0.7426 - val_loss: 0.5179 - val_precision: 0.3002 - train_loss: 0.5167 - train_accuracy: 0.7427 - train_precision: 0.3010 - train_AUC: 0.8282
# 9045/9045 ━━━━━━━━━━━━━━━━━━━━ 4s 487us/step
# /Users/leanderflottau/miniforge3/envs/IceCube/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - AUC: 0.6103 - accuracy: 0.5439 - loss: 0.7861 - precision: 0.1645 - val_AUC: 0.7896 - val_accuracy: 0.6742 - val_loss: 0.6391 - val_precision: 0.2499 - train_loss: 0.6393 - train_accuracy: 0.6739 - train_precision: 0.2511 - train_AUC: 0.7915
# Epoch 2/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 43s 4ms/step - AUC: 0.7251 - accuracy: 0.6245 - loss: 0.6453 - precision: 0.2118 - val_AUC: 0.8028 - val_accuracy: 0.7062 - val_loss: 0.5916 - val_precision: 0.2700 - train_loss: 0.5916 - train_accuracy: 0.7058 - train_precision: 0.2710 - train_AUC: 0.8052
# Epoch 3/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 44s 5ms/step - AUC: 0.7525 - accuracy: 0.6621 - loss: 0.6097 - precision: 0.2334 - val_AUC: 0.8085 - val_accuracy: 0.7100 - val_loss: 0.5825 - val_precision: 0.2735 - train_loss: 0.5824 - train_accuracy: 0.7098 - train_precision: 0.2748 - train_AUC: 0.8112
# Epoch 4/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 43s 5ms/step - AUC: 0.7639 - accuracy: 0.6816 - loss: 0.5949 - precision: 0.2452 - val_AUC: 0.8120 - val_accuracy: 0.7282 - val_loss: 0.5525 - val_precision: 0.2854 - train_loss: 0.5523 - train_accuracy: 0.7274 - train_precision: 0.2863 - train_AUC: 0.8149
# Epoch 5/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - AUC: 0.7759 - accuracy: 0.6951 - loss: 0.5802 - precision: 0.2561 - val_AUC: 0.8145 - val_accuracy: 0.7315 - val_loss: 0.5453 - val_precision: 0.2882 - train_loss: 0.5449 - train_accuracy: 0.7305 - train_precision: 0.2890 - train_AUC: 0.8175
# Epoch 6/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 47s 5ms/step - AUC: 0.7835 - accuracy: 0.7040 - loss: 0.5700 - precision: 0.2626 - val_AUC: 0.8163 - val_accuracy: 0.7348 - val_loss: 0.5369 - val_precision: 0.2908 - train_loss: 0.5364 - train_accuracy: 0.7340 - train_precision: 0.2917 - train_AUC: 0.8195
# Epoch 7/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - AUC: 0.7868 - accuracy: 0.7090 - loss: 0.5667 - precision: 0.2676 - val_AUC: 0.8178 - val_accuracy: 0.7377 - val_loss: 0.5313 - val_precision: 0.2931 - train_loss: 0.5307 - train_accuracy: 0.7370 - train_precision: 0.2941 - train_AUC: 0.8212
# Epoch 8/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - AUC: 0.7910 - accuracy: 0.7142 - loss: 0.5594 - precision: 0.2698 - val_AUC: 0.8187 - val_accuracy: 0.7385 - val_loss: 0.5287 - val_precision: 0.2938 - train_loss: 0.5279 - train_accuracy: 0.7378 - train_precision: 0.2948 - train_AUC: 0.8223
# Epoch 9/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 44s 5ms/step - AUC: 0.7932 - accuracy: 0.7145 - loss: 0.5570 - precision: 0.2711 - val_AUC: 0.8197 - val_accuracy: 0.7341 - val_loss: 0.5345 - val_precision: 0.2910 - train_loss: 0.5337 - train_accuracy: 0.7338 - train_precision: 0.2923 - train_AUC: 0.8234
# Epoch 10/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 44s 5ms/step - AUC: 0.7984 - accuracy: 0.7173 - loss: 0.5505 - precision: 0.2748 - val_AUC: 0.8205 - val_accuracy: 0.7435 - val_loss: 0.5215 - val_precision: 0.2978 - train_loss: 0.5206 - train_accuracy: 0.7430 - train_precision: 0.2989 - train_AUC: 0.8242
# Epoch 11/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 45s 5ms/step - AUC: 0.7994 - accuracy: 0.7213 - loss: 0.5506 - precision: 0.2787 - val_AUC: 0.8213 - val_accuracy: 0.7421 - val_loss: 0.5222 - val_precision: 0.2970 - train_loss: 0.5213 - train_accuracy: 0.7417 - train_precision: 0.2982 - train_AUC: 0.8251
# Epoch 12/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - AUC: 0.8008 - accuracy: 0.7230 - loss: 0.5462 - precision: 0.2784 - val_AUC: 0.8220 - val_accuracy: 0.7423 - val_loss: 0.5209 - val_precision: 0.2973 - train_loss: 0.5199 - train_accuracy: 0.7419 - train_precision: 0.2985 - train_AUC: 0.8259
# Epoch 13/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - AUC: 0.8043 - accuracy: 0.7236 - loss: 0.5431 - precision: 0.2805 - val_AUC: 0.8225 - val_accuracy: 0.7456 - val_loss: 0.5155 - val_precision: 0.2998 - train_loss: 0.5144 - train_accuracy: 0.7454 - train_precision: 0.3014 - train_AUC: 0.8266
# Epoch 14/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 39s 4ms/step - AUC: 0.8051 - accuracy: 0.7244 - loss: 0.5420 - precision: 0.2816 - val_AUC: 0.8232 - val_accuracy: 0.7481 - val_loss: 0.5118 - val_precision: 0.3020 - train_loss: 0.5107 - train_accuracy: 0.7479 - train_precision: 0.3037 - train_AUC: 0.8273
# Epoch 15/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 38s 4ms/step - AUC: 0.8056 - accuracy: 0.7264 - loss: 0.5393 - precision: 0.2810 - val_AUC: 0.8237 - val_accuracy: 0.7488 - val_loss: 0.5118 - val_precision: 0.3027 - train_loss: 0.5107 - train_accuracy: 0.7487 - train_precision: 0.3044 - train_AUC: 0.8279
# 9045/9045 ━━━━━━━━━━━━━━━━━━━━ 4s 453us/step
# /Users/leanderflottau/miniforge3/envs/IceCube/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 40s 4ms/step - AUC: 0.6190 - accuracy: 0.5462 - loss: 0.7960 - precision: 0.1673 - val_AUC: 0.7885 - val_accuracy: 0.6761 - val_loss: 0.6253 - val_precision: 0.2511 - train_loss: 0.6258 - train_accuracy: 0.6763 - train_precision: 0.2517 - train_AUC: 0.7900
# Epoch 2/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 39s 4ms/step - AUC: 0.7253 - accuracy: 0.6251 - loss: 0.6455 - precision: 0.2120 - val_AUC: 0.8022 - val_accuracy: 0.7031 - val_loss: 0.5875 - val_precision: 0.2685 - train_loss: 0.5880 - train_accuracy: 0.7027 - train_precision: 0.2691 - train_AUC: 0.8041
# Epoch 3/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 40s 4ms/step - AUC: 0.7509 - accuracy: 0.6616 - loss: 0.6140 - precision: 0.2337 - val_AUC: 0.8082 - val_accuracy: 0.7131 - val_loss: 0.5675 - val_precision: 0.2759 - train_loss: 0.5678 - train_accuracy: 0.7127 - train_precision: 0.2764 - train_AUC: 0.8103
# Epoch 4/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 38s 4ms/step - AUC: 0.7650 - accuracy: 0.6821 - loss: 0.5931 - precision: 0.2456 - val_AUC: 0.8121 - val_accuracy: 0.7208 - val_loss: 0.5545 - val_precision: 0.2816 - train_loss: 0.5547 - train_accuracy: 0.7201 - train_precision: 0.2817 - train_AUC: 0.8144
# Epoch 5/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 38s 4ms/step - AUC: 0.7740 - accuracy: 0.6937 - loss: 0.5830 - precision: 0.2547 - val_AUC: 0.8149 - val_accuracy: 0.7238 - val_loss: 0.5463 - val_precision: 0.2840 - train_loss: 0.5464 - train_accuracy: 0.7233 - train_precision: 0.2843 - train_AUC: 0.8174
# Epoch 6/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - AUC: 0.7789 - accuracy: 0.7001 - loss: 0.5755 - precision: 0.2591 - val_AUC: 0.8170 - val_accuracy: 0.7330 - val_loss: 0.5321 - val_precision: 0.2905 - train_loss: 0.5321 - train_accuracy: 0.7325 - train_precision: 0.2908 - train_AUC: 0.8196
# Epoch 7/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 51s 5ms/step - AUC: 0.7847 - accuracy: 0.7067 - loss: 0.5691 - precision: 0.2652 - val_AUC: 0.8186 - val_accuracy: 0.7310 - val_loss: 0.5336 - val_precision: 0.2898 - train_loss: 0.5335 - train_accuracy: 0.7304 - train_precision: 0.2899 - train_AUC: 0.8214
# Epoch 8/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 46s 5ms/step - AUC: 0.7904 - accuracy: 0.7101 - loss: 0.5618 - precision: 0.2689 - val_AUC: 0.8200 - val_accuracy: 0.7359 - val_loss: 0.5240 - val_precision: 0.2934 - train_loss: 0.5238 - train_accuracy: 0.7355 - train_precision: 0.2937 - train_AUC: 0.8229
# Epoch 9/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 44s 5ms/step - AUC: 0.7917 - accuracy: 0.7124 - loss: 0.5596 - precision: 0.2701 - val_AUC: 0.8210 - val_accuracy: 0.7355 - val_loss: 0.5264 - val_precision: 0.2935 - train_loss: 0.5262 - train_accuracy: 0.7351 - train_precision: 0.2940 - train_AUC: 0.8240
# Epoch 10/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 39s 4ms/step - AUC: 0.7968 - accuracy: 0.7166 - loss: 0.5534 - precision: 0.2752 - val_AUC: 0.8220 - val_accuracy: 0.7390 - val_loss: 0.5216 - val_precision: 0.2963 - train_loss: 0.5212 - train_accuracy: 0.7387 - train_precision: 0.2967 - train_AUC: 0.8251
# Epoch 11/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 40s 4ms/step - AUC: 0.7976 - accuracy: 0.7185 - loss: 0.5520 - precision: 0.2760 - val_AUC: 0.8229 - val_accuracy: 0.7354 - val_loss: 0.5260 - val_precision: 0.2941 - train_loss: 0.5256 - train_accuracy: 0.7353 - train_precision: 0.2949 - train_AUC: 0.8261
# Epoch 12/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - AUC: 0.7984 - accuracy: 0.7195 - loss: 0.5499 - precision: 0.2758 - val_AUC: 0.8237 - val_accuracy: 0.7435 - val_loss: 0.5133 - val_precision: 0.3002 - train_loss: 0.5128 - train_accuracy: 0.7432 - train_precision: 0.3008 - train_AUC: 0.8270
# Epoch 13/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - AUC: 0.8011 - accuracy: 0.7198 - loss: 0.5475 - precision: 0.2780 - val_AUC: 0.8243 - val_accuracy: 0.7405 - val_loss: 0.5186 - val_precision: 0.2983 - train_loss: 0.5180 - train_accuracy: 0.7402 - train_precision: 0.2989 - train_AUC: 0.8277
# Epoch 14/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - AUC: 0.8029 - accuracy: 0.7229 - loss: 0.5438 - precision: 0.2793 - val_AUC: 0.8249 - val_accuracy: 0.7441 - val_loss: 0.5139 - val_precision: 0.3010 - train_loss: 0.5132 - train_accuracy: 0.7439 - train_precision: 0.3017 - train_AUC: 0.8284
# Epoch 15/15
# 9498/9498 ━━━━━━━━━━━━━━━━━━━━ 45s 5ms/step - AUC: 0.8054 - accuracy: 0.7246 - loss: 0.5408 - precision: 0.2807 - val_AUC: 0.8254 - val_accuracy: 0.7434 - val_loss: 0.5148 - val_precision: 0.3006 - train_loss: 0.5141 - train_accuracy: 0.7432 - train_precision: 0.3014 - train_AUC: 0.8290
# 9045/9045 ━━━━━━━━━━━━━━━━━━━━ 5s 503us/step

# %%
plt.bar(range(4),AUC[:,0])
plt.yscale('log')
plt.xlabel('Fold')
plt.ylabel('AUC')
# Out:
# Text(0, 0.5, 'AUC')

# %%
print(np.mean(AUC[:,0]))
print(np.std(AUC[:,0]))
print(AUC)
# Out:
# 0.8250721512368868
# 0.0008533453317519031
# [[0.82563978 0.82925338]
#  [0.82405933 0.82821059]
#  [0.82443868 0.82786047]
#  [0.82615081 0.82903063]]

# %%
plt.plot(range(15),val_AUC[0,:],label='Fold 0')
plt.plot(range(15),val_AUC[1,:],label='Fold 1')
plt.plot(range(15),val_AUC[2,:],label='Fold 2')
plt.plot(range(15),val_AUC[3,:],label='Fold 3')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend()

# %%
relevant_features=['Area ID', 'Crime Code Description', 'Premise Description', 'Victim Age', 'Victim Descent', 'Time Occurred', 'Days Between', 'Reporting District','Victim Sex']
#relevant_features=['Victim Age']
Relevance=np.zeros(np.size(relevant_features))
#age_diffference=np.zeros((1,np.size(optimized_pred)))
k=0
for i in relevant_features:
    shuffled_testing=X_test_embed.copy()
    shuffled_testing[i]=np.array(shuffle(shuffled_testing[i]))
    unnötig2, shuffled_testing_onehot=set_features(X_train_embed,shuffled_testing)
    shuffled_prediction=model_optimized.predict(shuffled_testing_onehot)
    #print(shuffled_testing[i])
    #print(X_)
    if i=='Victim Age':
        age_difference=np.array(shuffled_testing[i]-X_test_embed[i])
        prediction_difference=shuffled_prediction-optimized_pred
    Relevance[k]=np.sqrt(np.mean(((optimized_pred)[shuffled_testing[i]!=X_test_embed[i]]-(shuffled_prediction)[shuffled_testing[i]!=X_test_embed[i]])**2))
    k+=1
# Out:
# 10854/10854 ━━━━━━━━━━━━━━━━━━━━ 5s 426us/step
# 10854/10854 ━━━━━━━━━━━━━━━━━━━━ 5s 427us/step
# 10854/10854 ━━━━━━━━━━━━━━━━━━━━ 5s 428us/step
# 10854/10854 ━━━━━━━━━━━━━━━━━━━━ 5s 426us/step
# 10854/10854 ━━━━━━━━━━━━━━━━━━━━ 5s 429us/step
# 10854/10854 ━━━━━━━━━━━━━━━━━━━━ 5s 428us/step
# 10854/10854 ━━━━━━━━━━━━━━━━━━━━ 5s 429us/step
# 10854/10854 ━━━━━━━━━━━━━━━━━━━━ 5s 430us/step
# 10854/10854 ━━━━━━━━━━━━━━━━━━━━ 5s 429us/step

# %%
Relevance
# Out:
# array([0.07887245, 0.36489958, 0.16124582, 0.02914402, 0.04178375,
#        0.02393479, 0.        , 0.07098585, 0.04246386])

# %%
#print(pred_diff)
#print(age_diff)
plt.scatter(age_difference,prediction_difference,s=0.1)
plt.xlabel('age difference')
plt.ylabel('prediction difference')
# Out:
# Text(0, 0.5, 'prediction difference')

# %%
plt.hist2d(age_difference,prediction_difference[:,0],bins=50,cmin=1,norm='log')
plt.xlabel('age difference')
plt.ylabel('prediction difference')
plt.colorbar()

# %%
np.size((merged_embed['arrest'])[merged_embed['arrest']==1])/np.size(merged_embed['arrest'])
# Out:
# 0.12773062209511735

# %%
merged_embed['Premise Description'].max()
# Out:
# 'YARD (RESIDENTIAL/BUSINESS)'

# %%
pred_diff
# Out:
# array([[-0.00040765],
#        [-0.02470024],
#        [ 0.00199109],
#        ...,
#        [-0.00467005],
#        [ 0.02635399],
#        [-0.02252054]], dtype=float32)

# %%
(X_test_embed['Crime Code Description'])[pred_diff[:,0]>0.04].max()
# Out:
# 'WEAPONS POSSESSION/BOMBING'

# %%
(X_test_embed['Premise Description'])[optimized_pred[:,0]>0.9].max()
# Out:
# 'YARD (RESIDENTIAL/BUSINESS)'

# %%
plt.bar(['Area','Crime','Premise','Age','Descent','Time','Days','District','Sex'],Relevance)
plt.xlabel('feature')
plt.ylabel('MSE')
# Out:
# Text(0, 0.5, 'MSE')

# %%
shuffled_prediction
# Out:
# array([[0.10036472],
#        [0.11938919],
#        [0.30695552],
#        ...,
#        [0.10847907],
#        [0.47731197],
#        [0.21016896]], dtype=float32)

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
optimized_pred
# Out:
# array([[0.09434645],
#        [0.05618045],
#        [0.24849491],
#        ...,
#        [0.06877212],
#        [0.496441  ],
#        [0.24983843]], dtype=float32)

# %%
merged_embed[relevant_features].head()
# Out:
#     Area ID                      Crime Code Description  \
# 4        21    VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 9         9  EMBEZZLEMENT, GRAND THEFT ($950.01 & OVER)
# 12       12          THEFT PLAIN - PETTY ($950 & UNDER)
# 14       15    SHOPLIFTING - PETTY THEFT ($950 & UNDER)
# 15       18           INTIMATE PARTNER - SIMPLE ASSAULT
#
#        Premise Description  Victim Age Victim Descent  Time Occurred  \
# 4   SINGLE FAMILY DWELLING        84.0              W           2300
# 9           OTHER BUSINESS        27.0              O            800
# 12             PARKING LOT        42.0              H           1200
# 14        DEPARTMENT STORE        12.0              O           2030
# 15  SINGLE FAMILY DWELLING        19.0              H            500
#
#     Days Between  Reporting District Victim Sex
# 4              7                2133          M
# 9             73                 904          F
# 12             9                1266          M
# 14             0                1511          M
# 15             1                1823          F
